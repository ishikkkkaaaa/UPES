# %%
import tweepy

# %%
consumer_key = "xxxxx"
consumer_secret = "xxxx" 
access_token = "xxxx" 
access_token_secret = "xxxx"

# %%
#authenticate to use the keys
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

#fetching all the public tweets from homepage
public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# RT @rangejhansi: #DIG_Jhansi_IN_News
# Print Media Coverage Of GoodWork Done By jhansi range.
# @jhansipolice
# @jalaunpolice
# @lalitpurpolice
# @Up…
# RT @rangejhansi: #DIG_Jhansi_IN_News
# Print Media Coverage Of GoodWork Done By jhansi range.
# @jhansipolice
# @jalaunpolice
# @lalitpurpolice
# @Up…
# RT @rangejhansi: Print Media Coverage Of GoodWork Done By jhansi range.
# @jhansipolice
# @jalaunpolice
# @lalitpurpolice
# @Uppolice
# @dgpup
# @adgzo…
# RT @rangejhansi: Print Media Coverage Of GoodWork Done By jhansi range.
# @jhansipolice
# @jalaunpolice
# @lalitpurpolice
# @Uppolice
# @dgpup
# @adgzo…
# RT @rangejhansi: #DIG_Jhansi_IN_News
# Print Media Coverage Of GoodWork Done By jhansi range.
# @jhansipolice
# @jalaunpolice
# @lalitpurpolice
# @Up…
# RT @rangejhansi: #DIG_Jhansi_IN_News
# Print Media Coverage Of GoodWork Done By jhansi range.
# @jhansipolice
# @jalaunpolice
# @lalitpurpolice
# @Up…
# RT @rangejhansi: Print Media Coverage Of GoodWork Done By jhansi range.
# @jhansipolice
# @jalaunpolice
# @lalitpurpolice
# @Uppolice
# @dgpup
# @adgzo…
# RT @jalaunpolice: . @Ravi_KumarIPS
# #UPPolice
# #jalaunpoliceInNews
# #UPPInNews
# #YourVoteMatters
#  #AssemblyElections2022
# #AgelessDemocrac…
# #LakhimpurKheri |  Union Minister Ajay Mishra Teni's son Ashish Mishra unlikely to be released today
#
# NDTV's Alok P… https://t.co/g3aahwQEW8
# RT @lalitpurpolice: #SPLalitpur के निर्देशन में जनपद पुलिस द्वारा किये जा रहे सराहनीय कार्यों का दैनिक समाचार पत्रों में प्रकाशन। https://t…
# RT @rangejhansi: #DIG_Jhansi_IN_News
# Print Media Coverage Of GoodWork Done By jhansi range.
# @jhansipolice
# @jalaunpolice
# @lalitpurpolice
# @Up…
# RT @jalaunpolice: . @Ravi_KumarIPS
# #UPPolice
# #jalaunpoliceInNews
# #UPPInNews
# #YourVoteMatters
#  #AssemblyElections2022
# #AgelessDemocracy…
# RT @adgzonekanpur: Print Media Coverage Of GoodWork Done By
# @auraiyapolice
# @jhansipolice
# #KanpurZonePolice
# #ADGZONE_KANPUR https://t.co/QZ…
# RT @lalitpurpolice: #SPLalitpur के निर्देशन में जनपद पुलिस द्वारा किये जा रहे सराहनीय कार्यों का दैनिक समाचार पत्रों में प्रकाशन। https://t…
# RT @kanpurdehatpol: श्रीमान अपर पुलिस महानिदेशक कानपुर जोन, कानपुर द्वारा जिलाधिकारी व पुलिस अधीक्षक महोदय के साथ माननीय प्रधानमंत्री महोदय…
# RT @rangejhansi: Print Media Coverage Of GoodWork Done By jhansi range.
# @jhansipolice
# @jalaunpolice
# @lalitpurpolice
# @Uppolice
# @dgpup
# @adgzo…
# RT @adgzonekanpur: #KanpurDehatPoliceINNews
# @kanpurdehatpol
# #KanpurZonePolice
# #ADG_ZONE_KANPUR
# #adgzonekanpur https://t.co/Bd07TqDUJz
# #BreakingNews
# उन्नाव में लड़की की हत्या का मामला, SP नेता के बेटे पर लड़की का अपहरण करके हत्या का आरोप, खेत में ज… https://t.co/nV3e0WQP6r
# RT @lalitpurpolice: #SPLalitpur के निर्देशन में जनपद पुलिस द्वारा किये जा रहे सराहनीय कार्यों का दैनिक समाचार पत्रों में प्रकाशन। https://t…
# RT @jalaunpolice: . @Ravi_KumarIPS
# #UPPolice
# #jalaunpoliceInNews
# #UPPInNews
# #YourVoteMatters
#  #AssemblyElections2022
# #AgelessDemocrac…

# %%
from nltk.tokenize import word_tokenize

# %%
# fetching all the public tweets from homepage
text1=tweet.text
print(text1)
# Out:
# RT @adgzonekanpur: Print Media Coverage Of GoodWork Done By
# @lalitpurpolice
# #lalitpurpolice
# #KanpurZonePolice
# #ADGZONE_KANPUR
# #YourVoteMat…

# %%
import nltk         
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/ishikakesarwani/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
print(word_tokenize(text1))
tokens=word_tokenize(text1)
# Out:
# ['RT', '@', 'adgzonekanpur', ':', 'Print', 'Media', 'Coverage', 'Of', 'GoodWork', 'Done', 'By', '@', 'lalitpurpolice', '#', 'lalitpurpolice', '#', 'KanpurZonePolice', '#', 'ADGZONE_KANPUR', '#', 'YourVoteMat…']

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/ishikakesarwani/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import nltk
from nltk.corpus import stopwords
filtered_sentence = []
stop_words = set(stopwords.words('english'))

# %%
for w in tokens:
    if w not in stop_words:
        filtered_sentence.append(w)

# %%
print(filtered_sentence)
# Out:
# ['RT', '@', 'adgzonekanpur', ':', 'Print', 'Media', 'Coverage', 'Of', 'GoodWork', 'Done', 'By', '@', 'lalitpurpolice', '#', 'lalitpurpolice', '#', 'KanpurZonePolice', '#', 'ADGZONE_KANPUR', '#', 'YourVoteMat…']

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/ishikakesarwani/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer
 
lemmatizer = WordNetLemmatizer()
lemitization=[]

# %%
for w in filtered_sentence:
    lemitization.append(lemmatizer.lemmatize(w,pos="a"))
print(lemitization)
# Out:
# ['RT', '@', 'adgzonekanpur', ':', 'Print', 'Media', 'Coverage', 'Of', 'GoodWork', 'Done', 'By', '@', 'lalitpurpolice', '#', 'lalitpurpolice', '#', 'KanpurZonePolice', '#', 'ADGZONE_KANPUR', '#', 'YourVoteMat…']

# %%
# word count
from collections import Counter
counts = Counter(lemitization)
print(counts)
# Out:
# Counter({'#': 4, '@': 2, 'lalitpurpolice': 2, 'RT': 1, 'adgzonekanpur': 1, ':': 1, 'Print': 1, 'Media': 1, 'Coverage': 1, 'Of': 1, 'GoodWork': 1, 'Done': 1, 'By': 1, 'KanpurZonePolice': 1, 'ADGZONE_KANPUR': 1, 'YourVoteMat…': 1})

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

# %%
# visualize wordcount 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = STOPWORDS,
                min_font_size = 10).generate(str(counts))

# %%
# plot the WordCloud image
plt.figure(figsize = (5, 5), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
